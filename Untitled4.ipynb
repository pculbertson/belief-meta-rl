# %%
import gym, torch, meta_env
import numpy as np
from utils.buffer import ReplayBuffer
from belief_models import LSTMEncoder, TransitionNet, RewardNet
from utils.distributions import get_cov_mat, log_transition_probs, log_rew_probs, product_of_gaussians, gaussian_product_posterior
from belief_policies import LSTMRandomShooting
import random

np.random.seed(0)
torch.manual_seed(0)
random.seed(0)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#setup environment
env = gym.make('MetaPendulum-v0')
if env.action_space.shape:
    dim_actions = env.action_space.shape[0]
    discrete_actions = False
else:
    dim_actions = env.action_space.n
    discrete_actions = True
dim_obs = env.observation_space.shape[0] if env.observation_space.shape else 1

#setup buffer
buffer_size = 10000
if env.action_space.shape:
    rb = ReplayBuffer(buffer_size,dim_obs,dim_actions)
else:
    rb = ReplayBuffer(buffer_size,dim_obs,1)

#training hyperparameters
num_epochs = 5000
global_iters = 0
num_train_steps = 50
max_logvar = 10.
state_noise = 1e-3
rew_noise = 1e-3
random_episodes=0
ep_length = 200
episode_repeat = 1

#model hyperparameters
trans_cov_type='diag'
trans_hs=200

rew_hs=200

encoder_type = 'single'
encoder_cov_type='diag'
encoder_hs = 200
encoder_num_layers = 2
latent_dim=10
latent_prior = torch.distributions.MultivariateNormal(torch.zeros(latent_dim),torch.eye(latent_dim))
test_batch_size = 100

trans_net = TransitionNet(dim_obs,dim_actions,latent_dim,cov_type=trans_cov_type,hs=trans_hs).to(device)
rew_net = RewardNet(dim_obs,dim_actions,latent_dim,hs=rew_hs).to(device)
encoder = LSTMEncoder(dim_obs,dim_actions,latent_dim,cov_type=encoder_cov_type,hs=encoder_hs,num_layers=encoder_num_layers).cuda()

#training parameters
t_learning_rate = 1e-3
t_optimizer = torch.optim.Adam(trans_net.parameters(),lr=t_learning_rate)

r_learning_rate = 1e-3
r_optimizer = torch.optim.Adam(rew_net.parameters(),lr=r_learning_rate)

q_learning_rate = 1e-3
q_optimizer = torch.optim.Adam(encoder.parameters(),lr=q_learning_rate)

#planner hyperparameters
num_traj = 1000
traj_length = 12
num_iters = 5
elite_frac = 0.1

batch_size = 50
batch_length = 75

if env.action_space.shape:
    init_action_dist = torch.distributions.MultivariateNormal(torch.zeros(dim_actions),torch.from_numpy((env.action_space.high-env.action_space.low)**2)*torch.eye(dim_actions))
    action_dist = [init_action_dist]*(traj_length-1)
else:
    init_action_dist = torch.distributions.Categorical(logits=torch.ones(env.action_space.n))
    action_dist = [init_action_dist]*(traj_length-1)

num_tasks = 100
m, l = np.random.uniform(0.1,5.,num_tasks), np.random.uniform(0.1,5.,num_tasks)
m_held, l_held = np.random.uniform(0.1,5.), np.random.uniform(0.1,5.)
policy = LSTMRandomShooting(trans_net, rew_net, encoder, init_action_dist, num_traj, traj_length, dim_obs, dim_actions, latent_dim, trans_cov_type, False, encoder_cov_type, max_logvar, device, det=False)
losses = np.array([])
rewards = []
curr_task = 0

for epoch in range(num_epochs):
    if epoch % episode_repeat == 0:
        print('new params!')
        env.set_params(m[curr_task],l[curr_task])
        curr_task += 1
        curr_task = curr_task % num_tasks
    rb.new_episode()
    if epoch > 0:
        for step in range(num_train_steps):
            if step == num_train_steps-1:
                seq_length = batch_length
            else:
                seq_length = random.choice(range(2,batch_length))
            samps = rb.random_sequences(batch_size,seq_length)
            
            q_optimizer.zero_grad()
            t_optimizer.zero_grad()
            r_optimizer.zero_grad()
            
            kl_divs, log_ts, log_rs = torch.zeros(batch_size), torch.zeros(batch_size), torch.zeros(batch_size)
        
            #assuming all sequences are full-length
            s,a_rb,r,sp = [torch.stack([torch.from_numpy(samp[k]).float().to(device) for samp in samps]) for k in ['o','a','r','op']]
            
            if discrete_actions:
                a = torch.squeeze(torch.nn.functional.one_hot(torch.from_numpy(a_rb).long(),num_classes=dim_actions)).float()
            else:
                a = a_rb
            
            q_ins = torch.cat((s,a,r,sp),axis=2).cuda()
            q_outs, _ = encoder(q_ins)
            q_means = torch.squeeze(q_outs)[:,:,:latent_dim].unsqueeze(-1)
            q_precs = torch.inverse(get_cov_mat(q_outs[:,:,latent_dim:],dim_obs,encoder_cov_type,device))
                
            post_means, post_precs = product_of_gaussians(q_means,q_precs)
            products_zipped = [product_of_gaussians(q_means[:,:t],q_precs[:,:t,:,:]) for t in range(1,seq_length+1)]
            stepwise_means = torch.squeeze(torch.stack([a[0] for a in products_zipped],axis=1))
            stepwise_precs = torch.stack([a[1] for a in products_zipped],axis=1)
            
            thetas = (post_means + torch.matmul(torch.inverse(post_precs),torch.randn_like(post_means))).view(batch_size,1,-1)#shape: [BxL]
            
            net_ins = torch.cat((s,a,thetas.expand(batch_size,seq_length,latent_dim)),axis=2).to(device)
            t_outs = trans_net(net_ins)
            r_outs = rew_net(net_ins)
            r_means, r_covs = r_outs[:,:,0], torch.clamp(r_outs[:,:,1],-max_logvar,max_logvar)
            t_means, t_covs = t_outs[:,:,:dim_obs], torch.clamp(t_outs[:,:,dim_obs:],-max_logvar,max_logvar)
            log_ts = torch.sum(log_transition_probs(t_means,t_covs,sp,cov_type=trans_cov_type,device=device),1)
            t_mse = torch.nn.MSELoss()(t_means.to(device),sp)
            log_rs = -torch.sum(torch.nn.MSELoss(reduction='none')(r_outs[:,:,0].to(device),torch.squeeze(r)),1)
            #log_rs = -torch.norm(r_outs[:,:,0].to(device)-torch.squeeze(r),p=1)
        
            prior_dist = torch.distributions.MultivariateNormal(stepwise_means[:,:-1,:],precision_matrix=stepwise_precs[:,:-1,:,:])
            post_dist = torch.distributions.MultivariateNormal(stepwise_means[:,1:,:],precision_matrix=stepwise_precs[:,1:,:,:])
            kl_divs = torch.sum(torch.distributions.kl.kl_divergence(post_dist,prior_dist))
            
            loss = torch.mean(kl_divs - log_ts - log_rs)
            
            loss.backward()
            
            q_optimizer.step()
            t_optimizer.step()
            r_optimizer.step()
        losses = np.append(losses,loss.cpu().detach().numpy())
        print(torch.mean(kl_divs),torch.mean(log_ts),torch.mean(log_rs))
        print('mse: ', t_mse)
        print(loss)

    s, d, ep_rew = env.reset(), False, 0.
    dyn_error, rew_error = 0, 0
    ep_step = 0
    latent_mean, latent_prec = torch.zeros(latent_dim).view(1,latent_dim,1).cuda(), torch.eye(latent_dim).view(1,latent_dim,latent_dim).cuda()
    hidden = None
    r =0.
    while not d and ep_step < ep_length:
        
        if epoch < random_episodes: #or epoch % episode_repeat == 0:
            a = np.array(env.action_space.sample())
        else:
            print(r)
            if hidden is None:
                a = policy.get_action(s,hidden,latent_mean,latent_prec)
            else:
                a = policy.get_action(s,[h.expand(encoder_num_layers,num_traj,encoder_hs).contiguous() for h in hidden],latent_mean,latent_prec)
        
        sp, r, d, _ = env.step(a) # take a random action
        s_n = s+np.random.multivariate_normal(np.zeros(dim_obs),state_noise*np.eye(dim_obs))
        sp_n = sp+np.random.multivariate_normal(np.zeros(dim_obs),state_noise*np.eye(dim_obs))
        r_n = r+np.random.normal(0.,rew_noise)
        rb.add_sample(s_n,a,r_n,sp_n,d)
        
        codes = torch.squeeze(latent_mean.expand(test_batch_size,latent_dim,1).cuda() + torch.matmul(torch.inverse(latent_prec).expand(test_batch_size,latent_dim,latent_dim).cuda(),torch.randn(test_batch_size,latent_dim,1).cuda())).cuda()
        s_torch = torch.from_numpy(np.array(s)).float().expand(test_batch_size,dim_obs).cuda()
        a_torch = torch.from_numpy(np.array(a)).float().expand(test_batch_size,dim_actions).cuda()
        net_ins = torch.cat((s_torch,a_torch,codes),axis=1).to(device)
        
        sp_hats = trans_net(net_ins)[:,:dim_obs]
        r_hats = rew_net(net_ins)[:,0]
        
        t_err = torch.mean(torch.nn.MSELoss()(torch.from_numpy(sp).float().expand(test_batch_size,dim_obs).to(device),sp_hats))
        r_err = torch.mean(torch.nn.MSELoss()(torch.from_numpy(np.array([r])).float().expand(test_batch_size,1).to(device),r_hats))
        
        dyn_error += t_err
        rew_error += r_err
        
        q_in = torch.cat([torch.from_numpy(np.array(k)).float() for k in [s,a,[r],sp]]).view(1,1,-1).cuda()
        q_out, hidden = encoder(q_in,hidden)
        new_mean, new_prec = torch.squeeze(q_out)[:latent_dim].view(1,latent_dim,1).cuda(), torch.inverse(get_cov_mat(torch.squeeze(q_out)[latent_dim:],dim_obs,encoder_cov_type,device)).view(1,latent_dim,latent_dim).cuda()     
        latent_mean, latent_prec = gaussian_product_posterior(latent_mean.cuda(),latent_prec.cuda(),new_mean,new_prec)
        
        if ep_step == 5:
            print('trans: ', sp, torch.mean(sp_hats,0))
            print('r: ', r, torch.mean(r_hats,0))    
        
        ep_rew += r
        global_iters += 1
        ep_step += 1
        s = sp
    rewards.append(ep_rew)
    print('ep_rew: ', ep_rew)
    print('traj errors: ', dyn_error,rew_error)
    #print(t_err,r_err)
env.close()
# Out:
# new params!
# 0.0
# -0.032583387269491816
# -0.039718253006431864
# -0.046765863623865686
# -0.0560993836028503
# -0.06903988792814081
# trans:  [0.96562094 0.25995422 0.55007588] tensor([ 0.3814, -0.8436, -0.5842], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -0.08480825697271427 tensor(0.0477, device='cuda:0', grad_fn=<MeanBackward1>)
# -0.08480825697271427
# -0.10215578954641241
# -0.1257527740834628
# -0.1511764084487141
# -0.1849172736432156
# -0.224137612360003
# -0.2750666594066259
# -0.3352641496961556
# -0.40824247752310544
# -0.4980472642277727
# -0.606402827476791
# -0.7393977730202667
# -0.8993305329788969
# -1.091664711810042
# -1.3230614318848049
# -1.600245297791225
# -1.9314890098550328
# -2.3245179379888863
# -2.7874446456050124
# -3.330924789536172
# -3.959874827157523
# -4.679392437325576
# -5.492885710189762
# -6.409143005388451
# -7.420664286168707
# -8.518006915732393
# -9.693569111196602
# -10.936890697239523
# -10.866902344865931
# -9.652935574202658
# -8.508822315817982
# -7.4398247698636375
# -6.4565027678446105
# -5.564529644336975
# -4.763876443380583
# -4.0531088205307535
# -3.4349509212183773
# -2.895605762684202
# -2.437424395233464
# -2.0442552466038695
# -1.7134325515121724
# -1.4397881866039863
# -1.212143694381333
# -1.0232942652167947
# -0.8671581368323152
# -0.7423671595015007
# -0.6429863290364242
# -0.5617482054936573
# -0.5041767055281993
# -0.4588061558958116
# -0.4300655366292448
# -0.41405143642616443
# -0.40891084194761573
# -0.4216355286647137
# -0.4418971158433545
# -0.48063539985116416
# -0.5321553180812524
# -0.6023771337273017
# -0.691949857531902
# -0.8052806053394399
# -0.9469217947242686
# -1.1186696977498891
# -1.3317483217821513
# -1.5864486258587822
# -1.895595853985687
# -2.263952290701507
# -2.6998867976644005
# -3.21378442107255
# -3.811379437422555
# -4.500479988530602
# -5.2838341350034845
# -6.166385163481416
# -7.146255562914798
# -8.21956633896854
# -9.377488228726984
# -10.609793912261676
# -11.15625432634581
# -9.940067408635338
# -8.785070836390062
# -7.702465211903208
# -6.698914559345618
# -5.782375171152021
# -4.954217624128348
# -4.217973046014298
# -3.570931363229457
# -3.0051326191755963
# -2.5173658760656945
# -2.101573798102724
# -1.7482232284100179
# -1.4510150076960708
# -1.2024227444931572
# -0.9972766343425191
# -0.8257080475966179
# -0.6858594247949896
# -0.5672013406310336
# -0.4714414548912278
# -0.3921106915718412
# -0.3292265924984711
# -0.27748806073163956
# -0.23348579804793734
# -0.1973722290231751
# -0.1707005187727017
# -0.14658233616131414
# -0.12751096057976224
# -0.11406706924725789
# -0.10413774204451123
# -0.09568915643139805
# -0.09229111873960873
# -0.09067338612259804
# -0.08911109156133949
# -0.09207363950268249
# -0.09870126736866675
# -0.10707964947135834
# -0.11934285848352993
# -0.1323323880184543
# -0.1548071885534269
# -0.17735689036174396
# -0.20592107206860827
# -0.244649771528839
# -0.28667713565704245
# -0.3433086158110249
# -0.41107372800962
# -0.493124955546696
# -0.5919625214028622
# -0.7135549062262803
# -0.8616398994990587
# -1.0409171951312919
# -1.2536059707956837
# -1.5097988279562933
# -1.8198829269173937
# -2.1855330488838187
# -2.6155083232717575
# -3.11884246217939
# -3.71078139669368
# -4.388697999293509
# -5.158825724461344
# -6.023669941960081
# -6.980738707102943
# -8.034408568702577
# -9.16592485574562
# -10.3650115370381
# -11.37343535939685
# -10.148163556220599
# -8.983925344631093
# -7.890161557636901
# -6.8815464974394605
# -5.958247760927495
# -5.120988495960069
# -4.377156277074048
# -3.7228675036048506
# -3.154040359369108
# -2.660331677825828
# -2.2418355541630244
# -1.889020387164689
# -1.5871802564738298
# -1.341002361078526
# -1.136475894525837
# -0.9702627663322801
# -0.8317647032973422
# -0.7218925999332683
# -0.6353860041334364
# -0.5709835309220288
# -0.5231964293285735
# -0.4910939343655103
# -0.475536647642998
# -0.4746866664057748
# -0.4837566790707653
# -0.5136804529671516
# -0.554775316921287
# -0.6172047947210659
# -0.6971335329863665
# -0.8010126826866771
# -0.9313603881365342
# -1.0910160462271319
# -1.2880891771518477
# -1.5277772918915342
# -1.8160747935661639
# -2.160361577688471
# -2.569600874290304
# -3.052809404168552
# -3.6155739725986193
# -4.267025767489329
# -5.013102326129582
# -5.85463576302758
# -6.7932199691997806
# -7.827340632570038
# -8.946803473447405
# -10.141529493023969
# -11.398755639530226
# -10.3506239610984
# -9.183328504291365
# -8.081864568513044
# -7.057022830674399
# -6.11408954276448
# ep_rew:  -594.4849627823787
# traj errors:  tensor(484.3328, device='cuda:0', grad_fn=<AddBackward0>) tensor(3887.5332, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(19.5830, device='cuda:0', grad_fn=<MeanBackward0>) tensor(61.5582, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-62.1349, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0631, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(20.1598, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -0.030370676574696533
# -0.024824798124017666
# -0.026326797549604652
# -0.02835507119044401
# -0.03389443398198756
# trans:  [0.98888976 0.14865077 0.52913169] tensor([1.1092, 0.1556, 0.6130], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -0.044640327911158004 tensor(-0.2081, device='cuda:0', grad_fn=<MeanBackward1>)
# -0.044640327911158004
# -0.05200561599957865
# -0.06863174240256607
# -0.08823517814344009
# -0.1132624300930104
# -0.14987636328040171
# -0.19628942258205226
# -0.2584948367151867
# -0.3434095074331601
# -0.4555187234602157
# -0.6108822896806159
# -0.8250094417130194
# -1.1092552254973282
# -1.4785856047419672
# -1.986652974894479
# -2.633193643421488
# -3.4715517434812364
# -4.549388768221378
# -5.881591239841077
# -7.483178077596276
# -9.350502270694696
# -11.37830631456044
# -13.505907319660567
# -12.526140671204555
# -10.640806539690736
# -8.842701664410733
# -7.1803101473974635
# -5.696245905455783
# -4.442366555447712
# -3.405530296144849
# -2.558484830969909
# -1.899732373491131
# -1.3878075320302226
# -1.0046099911152155
# -0.7262429060621647
# -0.5194339208462466
# -0.3731499495587981
# -0.26572546831086485
# -0.19473099564279245
# -0.1437019792168105
# -0.11222981867197065
# -0.09914584366314613
# -0.09547028001958655
# -0.10609126335171383
# -0.13264474389908396
# -0.1731021784940527
# -0.2353338447731848
# -0.32490055291795117
# -0.45033080489241933
# -0.6225589652446712
# -0.8569113729309427
# -1.1820430781829117
# -1.622126615909614
# -2.211636665368617
# -2.9826266448693666
# -3.9759665920025586
# -5.2135261450299035
# -6.732960802493965
# -8.516986184955599
# -10.524624512883602
# -12.68315030648911
# -13.623015445075783
# -11.670717341344778
# -9.781565953251414
# -8.013944855799087
# -6.413134443972024
# -5.0207284531206735
# -3.874569949172125
# -2.949428571612748
# -2.2282219284670886
# -1.674191635226828
# -1.2663378201555606
# -0.9651275482212924
# -0.7439733399630897
# -0.5944202328433986
# -0.5029144467235442
# -0.46610877484962526
# -0.4761160855985974
# -0.5359033881517912
# -0.6497316113236016
# -0.8345123207592531
# -1.101079886466274
# -1.4796274439670312
# -2.0037694021163204
# -2.715496364153073
# -3.6640439993239795
# -4.853628295938514
# -6.361743417630289
# -8.15338705328704
# -10.217475572312097
# -12.497458706041872
# -14.734095311736326
# -12.685974353337878
# -10.66039290847201
# -8.73090790349509
# -6.988032156075707
# -5.475101250148262
# -4.235011492566914
# -3.2261656286353135
# -2.456210031572625
# -1.8808437534376425
# -1.4787332827675939
# -1.1963145724648951
# -1.0440650511591048
# -1.0040366999813928
# -1.0642519024407082
# -1.2211353664171587
# -1.5125325775857374
# -1.9479462747352212
# -2.5721275462525433
# -3.4326983372391755
# -4.547654018306573
# -6.003908565271458
# -7.791933962184222
# -9.89537046467495
# -12.224842012745306
# -14.690123522665877
# -13.675552238389018
# -11.53815150116813
# -9.481186490477347
# -7.608376715125765
# -5.984129225970731
# -4.637819559501741
# -3.5769898090983308
# -2.7660250812533254
# -2.174227583742668
# -1.792302762305587
# -1.5842664964416486
# -1.5188049191988742
# -1.622554726174994
# -1.8981257093080564
# -2.37568854166873
# -3.0735813630135076
# -4.045312849101436
# -5.345712245988642
# -7.021125480402379
# -9.056492952172512
# -11.380428019280076
# -13.904701328804315
# -15.245090169528545
# -13.00247812549044
# -10.832000780665869
# -8.781500143148765
# -6.948917832817208
# -5.434098663138452
# -4.200803803828458
# -3.2868591905166387
# -2.657947342734177
# -2.265228775970131
# -2.093028154706735
# -2.136127496655092
# -2.4005990396125605
# -2.917211496458161
# -3.6970323423248916
# -4.80710629693028
# -6.303950524908155
# -8.196378895798107
# -10.447029220887327
# -12.99143378577158
# -15.653277766227216
# -14.455245341490373
# -12.176128286655008
# -9.970179845592673
# -7.988087234391516
# -6.278827955682225
# -4.893890857679085
# -3.848149041089234
# -3.107320303667161
# -2.64976005292687
# -2.467283430919079
# -2.5237528435869034
# -2.8352589619348305
# -3.444619024069248
# -4.390078283481373
# -5.712005682351193
# -7.463155105027866
# -9.59708419063738
# -12.11427293936247
# -14.555711031745288
# -15.518151877813873
# -13.21865654227899
# -10.959909246931746
# -8.847660911765864
# -7.008409391670871
# -5.486115744773202
# -4.297189937991876
# -3.4366424590268525
# -2.872273448385567
# -2.579721148305713
# -2.552016044401679
# -2.7816417440841397
# -3.2800827931660232
# -4.097348332128835
# -5.2806438807979985
# ep_rew:  -954.7658154412268
# traj errors:  tensor(696.4616, device='cuda:0', grad_fn=<AddBackward0>) tensor(3828.6123, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(5.2394, device='cuda:0', grad_fn=<MeanBackward0>) tensor(170.3811, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-58.6779, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.1596, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-106.4638, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -0.04970960850704882
# -0.059534649928926
# -0.07288395955359872
# -0.09032057043689523
# -0.11274796411519673
# trans:  [ 0.95199543 -0.30611224 -0.8693375 ] tensor([ 0.8546, -0.4124, -0.9525], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -0.14101438731678698 tensor(-0.1508, device='cuda:0', grad_fn=<MeanBackward1>)
# -0.14101438731678698
# -0.17636204220306495
# -0.21831615520093692
# -0.27177594309534725
# -0.3400428628143518
# -0.42111977041525245
# -0.5211971786775903
# -0.6429693526404692
# -0.7875087276134995
# -0.9651155203929442
# -1.1822670288120234
# -1.4387632515501199
# -1.7501311035755067
# -2.116614092255855
# -2.5495852421290293
# -3.057511944611148
# -3.6507537515921995
# -4.331395665115036
# -5.107501658329886
# -5.982247817671998
# -6.955161317744401
# -8.02331405446715
# -9.179241475526194
# -10.411971723139454
# -11.447419074477267
# -10.203140025844085
# -9.019882228005725
# -7.90983439622683
# -6.877981411760963
# -5.9355642584682515
# -5.082884161796888
# -4.321124509498879
# -3.6485145762223525
# -3.061071141412716
# -2.553119607179999
# -2.1178641020603526
# -1.7479280129039683
# -1.4358131970855141
# -1.1742540686795029
# -0.9564649080300256
# -0.7762927779513333
# -0.6282950641404625
# -0.5066055239230737
# -0.4103991668404763
# -0.33354773497558304
# -0.2741701540198605
# -0.2301877792192893
# -0.1989848531250735
# -0.18061532861579668
# -0.17704912739066148
# -0.18431719694677237
# -0.2038814779063625
# -0.23766485467617543
# -0.2836395680152172
# -0.3503960398575678
# -0.43530250674781507
# -0.5438585308572643
# -0.6764791686474777
# -0.8450142976122175
# -1.0472703138799409
# -1.294024014218379
# -1.594556199338937
# -1.9528185196413101
# -2.3793356579193983
# -2.8824001390893046
# -3.470783005937347
# -4.152837620459656
# -4.934883266201783
# -5.823815844455347
# -6.8137409061332015
# -7.904735158208729
# -9.090936960595457
# -10.362243345132196
# -11.704830598908856
# -10.424280039137209
# -9.188192451009959
# -8.031990780590162
# -6.958327093661194
# -5.979524732530935
# -5.095756967123579
# -4.308208728262734
# -3.614780584624969
# -3.0118505034682443
# -2.4928843285201734
# -2.0507443841576363
# -1.6776249884837977
# -1.3656565578891622
# -1.107297629400269
# -0.8956084318878008
# -0.7244215972947854
# -0.5883320003278578
# -0.48320357211621584
# -0.40528846845440686
# -0.3504026275013011
# -0.31901323238225304
# -0.3111020544582862
# -0.32332166404069457
# -0.3598881927930433
# -0.4193332605672202
# -0.503275662304464
# -0.620009215544494
# -0.7690684723616767
# -0.9575526678489963
# -1.19109399809344
# -1.479108980670293
# -1.826288937747001
# -2.244652555076644
# -2.741995208756925
# -3.3278831501955075
# -4.011438562342762
# -4.799199241372723
# -5.698983345311467
# -6.705960965751885
# -7.82225561981373
# -9.040467202322366
# -10.35068873696411
# -11.738870590664714
# -10.61325141502816
# -9.331720016461832
# -8.132133923183734
# -7.0198935524124915
# -6.007639197349405
# -5.095980692386513
# -4.286063888202733
# -3.5759197133588656
# -2.961029012943127
# -2.434964027229204
# -1.990096185849422
# -1.6182657144564048
# -1.3113468415365723
# -1.061681107832736
# -0.8620181165981904
# -0.7060022413124519
# -0.5915620225968269
# -0.511989868457025
# -0.4659785172591576
# -0.4513716751115377
# -0.4682127270306608
# -0.5182709679899216
# -0.5989356986554233
# -0.7186004355365457
# -0.8807477670079947
# -1.09064591732543
# -1.3544131324112638
# -1.68097163388338
# -2.079761166926806
# -2.561694604234824
# -3.1322599724753846
# -3.806797933788443
# -4.59005408489958
# -5.485052353299963
# -6.497443969658711
# -7.626648263843633
# -8.863072542923833
# -10.19916224627169
# -11.618846237206265
# -10.943261455930134
# -9.610306427758717
# -8.360168488749615
# -7.202354062134035
# -6.147958352948649
# -5.199126501748319
# -4.357528606396187
# -3.6214479814528353
# -2.986182462932974
# -2.445724047529598
# -1.9918090338024501
# -1.6161281787113277
# -1.3103891746447314
# -1.0668900305985773
# -0.8788701282627417
# -0.7407408523140347
# -0.6474029944180967
# -0.5952406443365197
# -0.587408827994
# -0.6196485915033648
# -0.693680840961822
# -0.812982547881845
# -0.9817904327433362
# -1.2074718738224943
# -1.4977582095882738
# -1.856313029565332
# -2.297231123564396
# -2.8290881782753483
# -3.4618688741914867
# -4.207040287583044
# -5.0695431002293
# -6.052674258637623
# -7.154554845440909
# -8.376419378775056
# -9.707458842023238
# -11.134844934814252
# -11.617593359552773
# -10.21223682137678
# ep_rew:  -689.0920361871651
# traj errors:  tensor(25.2209, device='cuda:0', grad_fn=<AddBackward0>) tensor(180.5012, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(1.2738, device='cuda:0', grad_fn=<MeanBackward0>) tensor(166.9202, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-18.8792, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0480, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-146.7672, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -1.7703638102659265
# -1.6563772292188863
# -1.565547592401423
# -1.4987110459082893
# -1.4556678738246958
# trans:  [0.36660368 0.9303772  0.00430487] tensor([0.6534, 1.1118, 0.1742], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -1.4311934125783194 tensor(-0.6079, device='cuda:0', grad_fn=<MeanBackward1>)
# -1.4311934125783194
# -1.4309128530199138
# -1.4502337711613467
# -1.4923483280543306
# -1.5531098159066405
# -1.6441679916489225
# -1.7531120058945042
# -1.8932817205101151
# -2.0613103064722975
# -2.259625969696809
# -2.4957806271099896
# -2.769858327584375
# -3.0878744584720708
# -3.446800071566255
# -3.8513956033215027
# -4.309672093757755
# -4.820430186290386
# -5.390187312345233
# -6.012263113152326
# -6.691073177829514
# -7.421707910586554
# -8.205875493446138
# -9.037651439425128
# -9.911629079497818
# -10.61272471280031
# -9.723428159684945
# -8.870472309832623
# -8.061666094635559
# -7.295619336568456
# -6.579688237179954
# -5.916506880842043
# -5.306860440255979
# -4.751479118224057
# -4.249095645215187
# -3.798627057872428
# -3.3981389313300343
# -3.0442404657654833
# -2.7348250840876913
# -2.4658370127916545
# -2.234193206080453
# -2.0378019338072764
# -1.8723656283488572
# -1.7362896751153096
# -1.6261922104336997
# -1.5411738111016924
# -1.4806362240123576
# -1.4391186820531543
# -1.4204026132580216
# -1.4230652464060676
# -1.4467620138608117
# -1.4927736470005142
# -1.559350547180142
# -1.6518596959245604
# -1.77132062022702
# -1.9141089569376388
# -2.088708917685161
# -2.2975716451688033
# -2.5421190171275105
# -2.8260964911929203
# -3.152967938292099
# -3.5258754175493614
# -3.946170061990478
# -4.420220802891372
# -4.948621219812307
# -5.533309416686259
# -6.174748292513699
# -6.871958603670255
# -7.624308850967265
# -8.429500126926174
# -9.27957448762055
# -10.171134853304142
# -10.372301906927063
# -9.488490955961007
# -8.641251684353351
# -7.836994635145776
# -7.081128928760759
# -6.376126477225952
# -5.722953244587133
# -5.123781426521848
# -4.578178065060251
# -4.085337647291788
# -3.6435284657890166
# -3.250387803045437
# -2.9030995792877805
# -2.5985656997633613
# -2.3335614188479994
# -2.104868774991185
# -1.909385609978995
# -1.7439732915964405
# -1.605509958962837
# -1.4938628857510938
# -1.4044982431942827
# -1.3378724527079113
# -1.2896421266033193
# -1.2626054440104193
# -1.2567292663628162
# -1.2710563456345492
# -1.2999827381910272
# -1.3527134532965341
# -1.4238115037854628
# -1.517826111011499
# -1.6372537902770294
# -1.7855335438874338
# -1.9599082155376815
# -2.1637221212013773
# -2.4029682365249254
# -2.685256783185432
# -3.00421099874479
# -3.3704012384623274
# -3.783907889890246
# -4.253567188060013
# -4.774316894161992
# -5.353096610624751
# -5.988835430283547
# -6.680197770069713
# -7.428253159957502
# -8.2254341305884
# -9.074338155953658
# -9.966876568950656
# -10.606642822681662
# -9.702352257235189
# -8.835292373580222
# -8.011476518129307
# -7.235200503058291
# -6.511119163831326
# -5.841769668715299
# -5.225818600230963
# -4.666933359868985
# -4.161783885914399
# -3.7088548211802856
# -3.307179876314418
# -2.9523991376402003
# -2.6426060520054953
# -2.373032795651951
# -2.1411152075482938
# -1.9431908118177343
# -1.7767002615803944
# -1.6376295937771788
# -1.526051302727605
# -1.4366737909493192
# -1.370383903717819
# -1.3254589665895729
# -1.3002431994573362
# -1.295328922270467
# -1.311854055274289
# -1.3467522627391153
# -1.402348368521909
# -1.4789861265929418
# -1.5808298312391502
# -1.7072921014036087
# -1.8613554155732046
# -2.0467009587972558
# -2.267524205803311
# -2.520443101986888
# -2.816275365157292
# -3.1558965079564443
# -3.5428093375620207
# -3.9808651643396566
# -4.469574030707827
# -5.017472546514839
# -5.621592315883896
# -6.2841094464689276
# -7.003601656538406
# -7.776578762191347
# -8.600596566156915
# -9.471724400401497
# -10.382443116347256
# -10.198842635119815
# -9.310756923375935
# -8.461833015322854
# -7.658592425695829
# -6.905581313023768
# -6.203603869343822
# -5.555521479611731
# -4.962137088756794
# -4.42318506001255
# -3.9374570373495503
# -3.502962335838092
# -3.117107009782206
# -2.776876196220886
# -2.47900688275025
# -2.22014194753829
# -1.9969602476904944
# -1.8062810174227215
# -1.6447738813629194
# -1.5099817225482486
# -1.400673492425433
# -1.3138629801976722
# -1.2474780470747153
# -1.1990809904389248
# -1.1689570546977135
# -1.1610712259488731
# -1.1695773343887161
# -1.1939908603710616
# ep_rew:  -787.4538095202576
# traj errors:  tensor(53.4580, device='cuda:0', grad_fn=<AddBackward0>) tensor(104.2453, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.5159, device='cuda:0', grad_fn=<MeanBackward0>) tensor(29.9134, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-8.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0383, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-21.3037, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -0.8150181742214366
# -0.8966969243764497
# -1.0586598201266193
# -1.3375869608938766
# -1.7397116017788183
# trans:  [0.13048434 0.99145037 3.12759586] tensor([0.0961, 1.1243, 3.3137], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -2.3088328001238048 tensor(-2.3595, device='cuda:0', grad_fn=<MeanBackward1>)
# -2.3088328001238048
# -3.0516303677983827
# -3.9967041229928606
# -5.201607491719101
# -6.653911120534024
# -8.367587152804958
# -10.304783082419272
# -12.342278091746628
# -13.106175568601879
# -11.292960898518743
# -9.483501605937963
# -7.766557354724128
# -6.23753916318934
# -4.913409823466278
# -3.817507194974579
# -2.9111085579514184
# -2.1979820836109845
# -1.6359646332977513
# -1.2075507365479654
# -0.8795438592829535
# -0.6411086697588163
# -0.4740288426956625
# -0.3672095845052151
# -0.3090006784550154
# -0.2922253005331022
# -0.30956044775741703
# -0.3610306015373366
# -0.43208339085601527
# -0.5392202122997145
# -0.6867750258133742
# -0.8889307571130173
# -1.1620505334294902
# -1.5268565964496208
# -2.0084960911089405
# -2.6357580900334177
# -3.438825428905987
# -4.444920706401506
# -5.671478570135781
# -7.119642768600276
# -8.761274977227414
# -10.541087802521199
# -12.463121052555435
# -12.433956076776125
# -10.601363763502643
# -8.892835029637384
# -7.323257225392835
# -5.929054435210683
# -4.753019437440789
# -3.764633065013545
# -2.9541631341746855
# -2.3079454672247515
# -1.8057444227837744
# -1.4254968176080225
# -1.1465435239125048
# -0.9514569127032182
# -0.8268698594876513
# -0.7618005032800665
# -0.7591624600590449
# -0.811540479908391
# -0.9300159901380325
# -1.1380803554307093
# -1.477597400666695
# -1.962379544984096
# -2.613801071170736
# -3.4193634013253846
# -4.452607374313968
# -5.781211128012351
# -7.357377232011979
# -9.13760568608161
# -11.145967111681477
# -13.218244736053594
# -12.356184885483055
# -10.55804875023105
# -8.780805628418864
# -7.11351340862651
# -5.692630748372842
# -4.433901209946326
# -3.389641617145394
# -2.5907009212584047
# -1.938496667273043
# -1.426486363870057
# -1.0460106325196896
# -0.7526104170677698
# -0.5582628052845788
# -0.4289263936782072
# -0.3652956752183123
# -0.34897456055858594
# -0.3679074004693599
# -0.4228281748183324
# -0.5066438543353661
# -0.6326157545996276
# -0.8056367344430406
# -1.0424486832499231
# -1.3614356914290842
# -1.7839767385076168
# -2.3525624812912724
# -3.0740690508738693
# -3.9865332483874023
# -5.11174161946777
# -6.47105250039902
# -8.0246404663806
# -9.86387043249941
# -11.712306079451883
# -13.176863667148446
# -11.3969783227047
# -9.680893281681284
# -8.033458843360657
# -6.537073403062494
# -5.215953480704596
# -4.09377066580842
# -3.198011240465094
# -2.477459774499711
# -1.9117022036851115
# -1.476795162486358
# -1.1492180195746706
# -0.9081651323350766
# -0.7365749958380854
# -0.6213790192520806
# -0.5518167154607907
# -0.5255308071706591
# -0.5459117212677457
# -0.6038388723001736
# -0.7118637923985605
# -0.9042693849707922
# -1.1740687635016172
# -1.5428721440625188
# -2.0790394785463104
# -2.7789255582521077
# -3.6612047198516917
# -4.798124527625393
# -6.183931194598647
# -7.841039436364572
# -9.732845644338278
# -11.778299582985259
# -13.789595065537362
# -11.948039620718411
# -10.158569681273235
# -8.40929543133233
# -6.804694384090023
# -5.3954791509606554
# -4.185187841297779
# -3.213634741768708
# -2.4079685332385807
# -1.8091342594461743
# -1.3253632467490486
# -0.9545875475504982
# -0.6705249306099962
# -0.4785288275680722
# -0.3308698789175604
# -0.2368291560967798
# -0.1731194993725599
# -0.1395682239335716
# -0.12501203593093965
# -0.1272322206447388
# -0.1412057407418291
# -0.17135750454422707
# -0.21712521688567146
# -0.27559872220232456
# -0.3551468181541029
# -0.47590016944017455
# -0.6377439307050784
# -0.846384667730681
# -1.1215640650028131
# -1.4878809993725188
# -1.9714645265710948
# -2.6023588499588617
# -3.41230980689863
# -4.426976339972907
# -5.726100653911111
# -7.252048527954082
# -9.003368170751662
# -10.89114872974502
# -12.908676745862294
# -12.495295466467908
# -10.626101963355781
# -8.851272212887748
# -7.25361785873597
# -5.86131147517556
# -4.620188697633204
# -3.6152251811631237
# -2.7969157866651737
# -2.147455975194853
# -1.6427283771048997
# -1.2572948729540243
# -0.9675427200334087
# -0.7518993338699204
# -0.5958575905958243
# -0.48631134083477656
# -0.4165065866536545
# -0.38166438587967294
# -0.3774679418171992
# -0.40460685050447903
# -0.4575546848169814
# -0.5549498243756386
# ep_rew:  -767.8818742861461
# traj errors:  tensor(18.0953, device='cuda:0', grad_fn=<AddBackward0>) tensor(95.6218, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.2751, device='cuda:0', grad_fn=<MeanBackward0>) tensor(201.2525, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-6.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-194.8035, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -1.854490468878723
# -1.725944007802599
# -1.6459699074527598
# -1.612448123183627
# -1.6245173080960083
# trans:  [ 0.24674475 -0.96908051 -0.61775581] tensor([ 0.3953, -1.0810, -0.5724], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -1.682611125545523 tensor(-1.5719, device='cuda:0', grad_fn=<MeanBackward1>)
# -1.682611125545523
# -1.7884626903316847
# -1.9450755008779392
# -2.156651323254184
# -2.428458090230068
# -2.7645194734047247
# -3.1759220001403947
# -3.665994307735866
# -4.241110487833919
# -4.904538523416075
# -5.659632765082294
# -6.5068067513688295
# -7.442435626458596
# -8.45408725215059
# -9.539432046132292
# -10.681877415169547
# -10.64798136894675
# -9.545925876888115
# -8.494491598198056
# -7.505117427494101
# -6.587264095068641
# -5.747898481174572
# -4.991185534109352
# -4.318459536317841
# -3.728473213828394
# -3.2178608244628055
# -2.7817195086679862
# -2.4142136670384016
# -2.1091294626018766
# -1.8603369621897627
# -1.6621453153590608
# -1.5095564055683708
# -1.3984336934734691
# -1.3238548300437745
# -1.2851330851980565
# -1.2853523418170218
# -1.323847238106781
# -1.4037439195702603
# -1.5226677434180316
# -1.6895715497155432
# -1.91015456512072
# -2.1835667976234583
# -2.523016893854761
# -2.9367534411089884
# -3.426693981960793
# -4.005508831249145
# -4.6768104597647495
# -5.44585458157176
# -6.3149744984828216
# -7.2810227762210875
# -8.33794406441681
# -9.474809449491485
# -10.676806622104019
# -10.89293525083414
# -9.729072605699036
# -8.619309964673835
# -7.575789554682016
# -6.608664140124239
# -5.725395479006557
# -4.930352546109058
# -4.224740294834795
# -3.606862087609306
# -3.072638583327447
# -2.6157691474194906
# -2.2267820152996203
# -1.9048827735995546
# -1.6387700353636614
# -1.4261477863711418
# -1.2589896017681241
# -1.1339527036258565
# -1.0468120608831601
# -0.9945158613092124
# -0.975200748797514
# -0.9881968221644034
# -1.0340329500328442
# -1.1134370620010663
# -1.2320053256191137
# -1.391440115711223
# -1.597985111098364
# -1.858210264496681
# -2.179730393715434
# -2.567981476645723
# -3.0364764598809804
# -3.591253526185318
# -4.239711844815124
# -4.988008150478135
# -5.838175183747887
# -6.787503759321737
# -7.841339424922093
# -8.984842186707494
# -10.206477130253955
# -11.489960305481146
# -10.328555244203901
# -9.146286290979715
# -8.031652777104755
# -6.995720090762275
# -6.04552061472157
# -5.186811572609075
# -4.421978926565154
# -3.7501060609315306
# -3.1674466613392083
# -2.6681072053483774
# -2.2447979404759226
# -1.889537019051728
# -1.594236487236317
# -1.3506636605803213
# -1.153016651102305
# -0.993852830532474
# -0.8680211030442073
# -0.7710113261334315
# -0.6986386281385316
# -0.6475888798478558
# -0.6177263169328707
# -0.6091111809525548
# -0.6217757059773885
# -0.6570625599054826
# -0.7161573353558648
# -0.8008143996043786
# -0.9157113499844088
# -1.0648461901022053
# -1.2528540950036453
# -1.4886239935986791
# -1.7816537313721532
# -2.1346562583641493
# -2.5636337996963467
# -3.073770903541402
# -3.676214468866829
# -4.378756006456343
# -5.183318144661497
# -6.102910117815032
# -7.130752057655503
# -8.261562285740716
# -9.488048093418408
# -10.790211187432694
# -11.238296155275483
# -9.971132631752523
# -8.765997398102842
# -7.63355504170569
# -6.589764024114064
# -5.640968220043845
# -4.790974291805485
# -4.04054226970929
# -3.386987504667628
# -2.8248348954857407
# -2.34394219266392
# -1.9382324786957663
# -1.6020401847124766
# -1.319554573391479
# -1.089545421926711
# -0.9040626565889167
# -0.7530318401407797
# -0.6356893008009292
# -0.5424319178529133
# -0.47443693566206735
# -0.42345668846256346
# -0.3894146771279598
# -0.37074356934701697
# -0.3665806788546335
# -0.37667901703881906
# -0.4017065358534006
# -0.4426686332553238
# -0.5015388724550718
# -0.581022425569493
# -0.6846943382345135
# -0.8170890645273519
# -0.9823550064410632
# -1.1893415725966778
# -1.4458161175269448
# -1.7597135210024362
# -2.138013385521449
# -2.5956006535522667
# -3.140112168044674
# -3.785155086964829
# -4.538344012950178
# -5.40385441272219
# -6.383881723551004
# -7.4783661283731515
# -8.678550990207892
# -9.971688426989
# -11.341034443510685
# -10.91997787427386
# -9.63055580484998
# -8.410985235628198
# -7.275525788622877
# -6.2342372186449495
# -5.294175455613371
# -4.458531374585981
# -3.726525086898297
# -3.093910499472547
# -2.553786588302241
# -2.097519518690812
# -1.7156126068492397
# -1.3984234417011265
# -1.1366889965693225
# ep_rew:  -771.0290985652107
# traj errors:  tensor(14.4891, device='cuda:0', grad_fn=<AddBackward0>) tensor(53.0010, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.1924, device='cuda:0', grad_fn=<MeanBackward0>) tensor(270.0017, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-4.9552, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-264.8541, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -5.601829151687158
# -5.561905380380661
# -5.572785419164242
# -5.634300031851908
# -5.751126798926109
# trans:  [-0.7788126  -0.62725668 -0.78995794] tensor([-0.7021, -0.7733, -0.8094], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -5.917416927040653 tensor(-5.3853, device='cuda:0', grad_fn=<MeanBackward1>)
# -5.917416927040653
# -6.135565241808195
# -6.403083559927786
# -6.72221813048843
# -7.088454280753182
# -7.500395483356422
# -7.954848079267065
# -8.447420544666107
# -8.973923896286443
# -9.528254829461558
# -10.104169590833983
# -9.741277980207801
# -9.185313913213738
# -8.645664129734547
# -8.128378139293982
# -7.63887271463358
# -7.181859906430937
# -6.761308669979241
# -6.380443490242273
# -6.041779661732854
# -5.747190960025914
# -5.498002105981401
# -5.295096218369047
# -5.139026579364277
# -5.030122384235927
# -4.968579392958093
# -4.954528172327035
# -4.9880746000577725
# -5.0688715288997646
# -5.195438859663062
# -5.374887801121824
# -5.606320320404239
# -5.884840175145985
# -6.2136718159916535
# -6.579838519723492
# -6.998508656485646
# -7.461685114386114
# -7.960594071813415
# -8.49853213411339
# -9.071399485218004
# -9.670421191270897
# -10.220331759642015
# -9.614921638868418
# -9.026218371504127
# -8.463046951874944
# -7.92225929405906
# -7.414964078011848
# -6.949049714833907
# -6.518488903261824
# -6.1363696933846175
# -5.799851834376569
# -5.51827906474747
# -5.29250795936378
# -5.118367150233193
# -5.002383817810111
# -4.939342162493262
# -4.936187600277656
# -4.98482628640307
# -5.091921182435081
# -5.254155088625071
# -5.47309703454864
# -5.7495235522874815
# -6.0813863551918645
# -6.467588822969287
# -6.908499478856592
# -7.399749075410927
# -7.9386440685811515
# -8.52029340075964
# -9.138997634135203
# -9.787987937702614
# -10.17975785029178
# -9.533568984501088
# -8.90367719259961
# -8.29729369400664
# -7.720892521990131
# -7.1800942399359915
# -6.679590230459866
# -6.223116637375393
# -5.81348167380693
# -5.452643526423525
# -5.141830051509235
# -4.881687130673506
# -4.672440526092773
# -4.514056243797941
# -4.40638619199263
# -4.349288547272394
# -4.342715042226266
# -4.386759935715479
# -4.478785052849392
# -4.626285527704737
# -4.830894234224951
# -5.0892149070246315
# -5.402309733880543
# -5.771833628233111
# -6.1921508523942315
# -6.664955415850718
# -7.189081575721499
# -7.7618404023052845
# -8.374031540802235
# -9.029113243645218
# -9.71453797020829
# -10.325676312882166
# -9.637830327627388
# -8.970357719757592
# -8.327538871223995
# -7.712865237485068
# -7.141227894351514
# -6.6109626527587055
# -6.127129928938444
# -5.692045124017066
# -5.312275742509451
# -4.988449573822879
# -4.719537184819338
# -4.515487408824564
# -4.368243991143838
# -4.280801553891956
# -4.252945799917117
# -4.2824123770784155
# -4.374917088070595
# -4.525735589952449
# -4.737030593841749
# -5.010036395542526
# -5.34532804153742
# -5.743196703674202
# -6.202654898912124
# -6.721555456879651
# -7.297702530178693
# -7.92760816590314
# -8.60586560864106
# -9.325146768899057
# -10.077147942286931
# -10.078034339057835
# -9.345446994048526
# -8.63648125274262
# -7.95897170637564
# -7.319770928637145
# -6.724606956307439
# -6.178000743975904
# -5.683256823537463
# -5.242530359647367
# -4.856962957282201
# -4.52687082963682
# -4.251964034715448
# -4.031574718465695
# -3.8648747627870006
# -3.75106747406348
# -3.687093984037973
# -3.680563734739299
# -3.7236741444212034
# -3.819641087456776
# -3.9723888126201756
# -4.179411451900067
# -4.44622502003057
# -4.778238435545876
# -5.158711734187799
# -5.6039401102218385
# -6.111576116942631
# -6.678032500822401
# -7.304706742421969
# -7.981998711829993
# -8.694579004164444
# -9.456287649666866
# -10.255042366096301
# -9.996645657536769
# -9.228695956750315
# -8.486384327521897
# -7.782125742521879
# -7.119758635308417
# -6.50527808806835
# -5.941642972736217
# -5.434562156806226
# -4.985270143282761
# -4.598947897763464
# -4.270501115725228
# -4.006545702263976
# -3.8057921722842027
# -3.666563437219862
# -3.589100934807264
# -3.571574790250918
# -3.6138613574408294
# -3.716211735373204
# -3.8793929207304045
# -4.1074212826303365
# -4.3989695815113645
# -4.755549489807747
# -5.178139179052462
# -5.670102247180212
# -6.229674052785931
# -6.855627613159546
# -7.5449174298007
# -8.29163823560226
# -9.08974635456874
# -9.930382879344878
# -10.448882900974406
# ep_rew:  -1290.7398911179941
# traj errors:  tensor(3.2050, device='cuda:0', grad_fn=<AddBackward0>) tensor(83.7941, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.1280, device='cuda:0', grad_fn=<MeanBackward0>) tensor(201.1859, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-4.5934, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-196.4644, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -0.19118042795743828
# -0.18073966586178744
# -0.17716944942605245
# -0.18073873968506476
# -0.19167425044144631
# trans:  [0.89259881 0.45085181 0.40740179] tensor([0.9467, 0.4372, 0.3367], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -0.21128789989328775 tensor(-0.4396, device='cuda:0', grad_fn=<MeanBackward1>)
# -0.21128789989328775
# -0.23935907278227325
# -0.27662262343685823
# -0.3260372276650786
# -0.39001832335273
# -0.47163928331616006
# -0.5747352566753284
# -0.7040176360339583
# -0.8626495250720861
# -1.0599320100408258
# -1.3038514424666023
# -1.6016228491656908
# -1.9627007787836575
# -2.3962122858126342
# -2.9152085579605673
# -3.5311772883235037
# -4.252687556840907
# -5.086885248899282
# -6.040499539724687
# -7.111320154627523
# -8.293134870333423
# -9.57790241403116
# -10.947126502662213
# -11.4017014572496
# -10.070365859477297
# -8.806930703393673
# -7.625626264864895
# -6.536305715700485
# -5.549382738771769
# -4.669074287341899
# -3.8961499699932656
# -3.2275434074595757
# -2.6567113355135765
# -2.1745073716153582
# -1.772078395380032
# -1.4396945056339698
# -1.165010624393936
# -0.9403335176982409
# -0.7606910318826663
# -0.6115354658031058
# -0.49484929018411317
# -0.3979030447120388
# -0.32403645510865847
# -0.2633829226015369
# -0.21538695038060007
# -0.1776909519776127
# -0.14838821883900713
# -0.12358601966199091
# -0.10939782610046925
# -0.09628387050616805
# -0.08975594899982349
# -0.08584446923802685
# -0.08557217412829453
# -0.08890525300486479
# -0.0960870718581182
# -0.10743584442307202
# -0.12357331418800971
# -0.1453479794120727
# -0.17389582684822766
# -0.21069206408015326
# -0.2576161981052655
# -0.3170315047481266
# -0.3918794450611418
# -0.48578853486699514
# -0.6031952721404845
# -0.749471595414789
# -0.9310485406662514
# -1.1536864424970923
# -1.4282690175367383
# -1.7649044496895792
# -2.1720272295101575
# -2.6621820332374524
# -3.2463198571249943
# -3.9347713153201025
# -4.736272186772346
# -5.6558732866619
# -6.696159263333908
# -7.854879017983388
# -9.121007599914051
# -10.480144813632748
# -11.915220942717234
# -10.591229472977515
# -9.282971852648968
# -8.053823287821498
# -6.916927905726575
# -5.8822859486948245
# -4.955893949205889
# -4.139388653710284
# -3.4302865128992965
# -2.8226970133715166
# -2.3082933274959445
# -1.8773230177607532
# -1.5195007385670976
# -1.2247012344596284
# -0.9834351022342369
# -0.7871304827567027
# -0.6282623904763025
# -0.5003744338680778
# -0.39803226474599296
# -0.31673946182926516
# -0.2528378233852618
# -0.20340667910806845
# -0.1661702631703583
# -0.1394183166092301
# -0.12194259509419182
# -0.11299049819599159
# -0.11223629932703866
# -0.11977019462783872
# -0.13610541421100136
# -0.1622037999560083
# -0.19952041776048252
# -0.2500677996722765
# -0.3165001312711809
# -0.40221688105065534
# -0.5114836942348915
# -0.6495654220316834
# -0.8228614110234248
# -1.0390260909616873
# -1.3070480882102156
# -1.633818572330635
# -2.036829495795417
# -2.522307724026455
# -3.1047027886346643
# -3.793510013002882
# -4.600191181631838
# -5.530284537080396
# -6.587523714683061
# -7.768120639148555
# -9.068073784518088
# -10.467594776471001
# -11.948168531354712
# -10.804700605976358
# -9.447106202189246
# -8.17232018199532
# -6.994236056146898
# -5.9235675508228764
# -4.9667972355072045
# -4.125728829248318
# -3.3977216475641545
# -2.776470191197786
# -2.253078457888495
# -1.8171784058630018
# -1.4579128646954973
# -1.164692976881076
# -0.9277142217443206
# -0.7382607245141206
# -0.5888473212189528
# -0.47325108045613506
# -0.3864770462815678
# -0.3246928664492479
# -0.2851571249893801
# -0.2661580899021539
# -0.2669735230889647
# -0.2878578880674705
# -0.3300601828166579
# -0.39587307900831026
# -0.4887113821636262
# -0.613214312683113
# -0.7753609669181607
# -0.9825807661559732
# -1.243830120670308
# -1.5679950317951303
# -1.9667683721150702
# -2.4535574334403725
# -3.0411801818046653
# -3.7406419508350672
# -4.56582535910945
# -5.5223879048367275
# -6.612420522721057
# -7.834124271949335
# -9.17630044515026
# -10.624613739447353
# -12.159961528403784
# -10.86401677336128
# -9.466094316140268
# -8.156492915769196
# -6.949635534895654
# -5.856559020782996
# -4.883748861361661
# -4.032675695058623
# -3.3001046209791984
# -2.6790014268394016
# -2.1597412104170584
# -1.731338275179195
# -1.382505825145232
# -1.1024582661973226
# -0.8814501896608851
# -0.7110932443024673
# -0.5845101681858397
# -0.4963847395678352
# -0.44295684469758945
# -0.4219995986898234
# -0.4328037602529334
# -0.4761846260527943
# ep_rew:  -576.691914705678
# traj errors:  tensor(3.2181, device='cuda:0', grad_fn=<AddBackward0>) tensor(15.0486, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.1632, device='cuda:0', grad_fn=<MeanBackward0>) tensor(322.3772, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-2.1202, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-320.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -0.1278497864768777
# -0.18527574559427032
# -0.2714480120286616
# -0.3973630969807282
# -0.5786099142430012
# trans:  [ 0.71790901 -0.69613695 -2.45725445] tensor([ 0.7255, -0.7072, -2.1767], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -0.8367299424732323 tensor(-0.7730, device='cuda:0', grad_fn=<MeanBackward1>)
# -0.8367299424732323
# -1.1987047327280191
# -1.6995496147503029
# -2.3919822993469517
# -3.3166605595051566
# -4.53444174096289
# -6.039648595393136
# -7.875404539370004
# -10.060689750902005
# -12.438950396839665
# -14.921810491799572
# -13.087903915142656
# -10.984709227259913
# -8.956051299733536
# -7.10213855369614
# -5.492531985678188
# -4.163702046660967
# -3.1132091297019673
# -2.31253323482242
# -1.721674405053099
# -1.300087100467974
# -1.0129473824968243
# -0.8339102110689623
# -0.745912368140665
# -0.7412347976973472
# -0.8215742915629233
# -0.9984962374357864
# -1.292358210252521
# -1.730649849382765
# -2.3584897647365057
# -3.2269492805768616
# -4.388648828041338
# -5.892670712035148
# -7.805933416519267
# -10.063276512997847
# -12.6176368217452
# -15.30377874845937
# -14.139658094957262
# -11.88805212300728
# -9.696610685457882
# -7.682759388722438
# -5.9423695729851485
# -4.523659708788628
# -3.427803312336732
# -2.625615468865547
# -2.0766705150648472
# -1.7436255374878944
# -1.6007083683832908
# -1.6380739510257316
# -1.863946204557566
# -2.303437471097472
# -2.9913711965790353
# -3.988063434643421
# -5.3450760301047415
# -7.116997557286919
# -9.345018183354142
# -11.94975734609652
# -14.567800198756085
# -15.49548271111404
# -13.195890235470607
# -10.905966736694866
# -8.745132032220019
# -6.831190916721999
# -5.240030800426589
# -3.9941567548973915
# -3.0755874265968415
# -2.447232326840951
# -2.071292209801342
# -1.9211666647435033
# -1.9870993772780499
# -2.275550315560492
# -2.807743974970568
# -3.658155974136445
# -4.832202168777937
# -6.426644534588326
# -8.459887211002568
# -10.920277869579389
# -13.560653357310064
# -15.956488909278633
# -14.182657063991476
# -11.878558187004812
# -9.648797322755739
# -7.617631595956111
# -5.882090787981578
# -4.487218793509923
# -3.4301040224686696
# -2.6793466579911605
# -2.1955134506373586
# -1.9458435666015141
# -1.9127971339912608
# -2.098396584319486
# -2.5222037876094205
# -3.1981228335103205
# -4.205528289842354
# -5.636102367624894
# -7.500682721334175
# -9.81145693777568
# -12.470891756382494
# -14.845178508298833
# -15.214812852563353
# -12.908755898364054
# -10.630913515489238
# -8.496547156175074
# -6.619723768087239
# -5.069840648429693
# -3.863639944714073
# -2.9798008458748013
# -2.3802657698081773
# -2.0278469887432427
# -1.8973495291536793
# -1.9815355188839041
# -2.292170567432097
# -2.853961667341055
# -3.696945921052759
# -4.912970952344067
# -6.5627009070474545
# -8.625194962120693
# -11.106379771463255
# -13.715941928958728
# -16.131107288071725
# -14.033490069691021
# -11.729498273686401
# -9.508204266360679
# -7.49354769519397
# -5.779597896668153
# -4.407823536853784
# -3.3727116856626145
# -2.64172895398099
# -2.175543846310982
# -1.9423055314118298
# -1.9257294366265807
# -2.1292149464373322
# -2.57541891678987
# -3.292033666299798
# -4.377170319588224
# -5.859333258532177
# -7.796531068409236
# -10.117855023034812
# -12.837044927903467
# -15.142649480716997
# -14.926537146135944
# -12.624113255973901
# -10.357361747575826
# -8.24941940206274
# -6.410306433839056
# -4.902768760834828
# -3.7378059006369173
# -2.8909063549422194
# -2.323294154353806
# -1.998757431722647
# -1.8940232364585514
# -2.0042357133962576
# -2.3454858942012646
# -2.9512026649304883
# -3.836847937677383
# -5.10614680014316
# -6.781986716030371
# -8.937984966392706
# -11.496412514065096
# -14.01613452157869
# -16.07769632784238
# -13.7429847698953
# -11.439773991227737
# -9.236093295578852
# -7.254724338464285
# -5.583657698442692
# -4.257413346417691
# -3.265621593885293
# -2.5738006380407312
# -2.1430646707540983
# -1.943575258288173
# -1.9621128682898497
# -2.2058163574321332
# -2.7018951894667897
# -3.4900309713752
# -4.624429916482488
# -6.146133788794438
# -8.116095604137426
# -10.549140339752888
# -13.19673923583785
# -15.54826422308458
# -14.54601363028873
# -12.242338155169065
# -9.993472097183208
# -7.923677538213175
# -6.136710242998158
# -4.686304656476063
# -3.576161782928883
# -2.777998544567435
# -2.252469935890704
# -1.9649159883572869
# -1.8947756780511706
# -2.037171196854072
# -2.3968104049353305
# ep_rew:  -1216.7906782045322
# traj errors:  tensor(78.9484, device='cuda:0', grad_fn=<AddBackward0>) tensor(331.5324, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.2881, device='cuda:0', grad_fn=<MeanBackward0>) tensor(274.6668, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-4.8009, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-269.5779, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -1.0427714370034158
# -1.1112317892956243
# -1.2062841003341065
# -1.318306561329419
# -1.459051857426713
# trans:  [0.2807209  0.95978944 1.27615517] tensor([0.3217, 0.9696, 1.3671], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -1.6238475766482185 tensor(-1.6107, device='cuda:0', grad_fn=<MeanBackward1>)
# -1.6238475766482185
# -1.821200806374563
# -2.045060101169009
# -2.3086218092786797
# -2.6181499600506015
# -2.9634047209443084
# -3.3628505075624764
# -3.8118813756374825
# -4.316938204496176
# -4.880950226934908
# -5.508618458811797
# -6.197358357361437
# -6.946650305640997
# -7.757556671687703
# -8.627091385514817
# -9.548969086417902
# -10.516740950316521
# -10.229075888787294
# -9.293577084621296
# -8.401469704366303
# -7.558351811934756
# -6.7686628530615405
# -6.035281108111777
# -5.357705058029207
# -4.740302071646094
# -4.181993862726456
# -3.6835567037148262
# -3.237929500619756
# -2.844805517520207
# -2.500762066324911
# -2.2040849590266247
# -1.9450056511726417
# -1.7234724626995976
# -1.5383959857391722
# -1.3791593615580753
# -1.2478533439983557
# -1.1409956533366494
# -1.0552531890491867
# -0.9883808191055011
# -0.9392327435622542
# -0.9065072069837942
# -0.8895225719216828
# -0.8877829770257151
# -0.9008571294844342
# -0.9296149185233222
# -0.9735981013662217
# -1.035331297265267
# -1.1153784108938416
# -1.216527690632679
# -1.340746788884492
# -1.490204047118611
# -1.668681985699997
# -1.8768611238664714
# -2.121800569800933
# -2.4051395250520966
# -2.7318124792158915
# -3.105357806672191
# -3.5326993890741267
# -4.01001005869469
# -4.543524642452582
# -5.1408652658277925
# -5.792389856160805
# -6.506971354349074
# -7.281171218846947
# -8.114956472772189
# -9.002316928527488
# -9.935949347193798
# -10.78749565307617
# -9.835390311391118
# -8.920670040043621
# -8.052866244085841
# -7.235142649986765
# -6.470229165145334
# -5.763934778432633
# -5.114783891039063
# -4.5269049380130655
# -3.9953259078198844
# -3.52006238369206
# -3.0952911045312845
# -2.7202872820696635
# -2.3922627690580964
# -2.1058125937103496
# -1.858124390751048
# -1.645019661506669
# -1.4634507883278232
# -1.3098112956814776
# -1.1811757061643502
# -1.0750818319070021
# -0.9888232662372967
# -0.9245048466950093
# -0.8697537774124778
# -0.8377361543919256
# -0.8149711632738825
# -0.8132740108346914
# -0.8232452023580995
# -0.8466260848902043
# -0.8864587522741332
# -0.9425105953814449
# -1.019941907559026
# -1.1119094770826219
# -1.2262760999056272
# -1.3651032027394567
# -1.5319471179033095
# -1.7215273355884708
# -1.9483908828252954
# -2.210039909023362
# -2.5094806215879766
# -2.853186470956711
# -3.2466028651344985
# -3.68951509521934
# -4.196696807945411
# -4.752259599196298
# -5.373960965379886
# -6.060811970017221
# -6.811020515973066
# -7.622906840130254
# -8.494439273555068
# -9.421450737374295
# -10.396061565180165
# -10.387692286634616
# -9.433979378659728
# -8.523852539958906
# -7.663126527267461
# -6.856452352798763
# -6.106038602186474
# -5.413027552011461
# -4.781841409838688
# -4.211443258825972
# -3.7013121456307427
# -3.2461022427590867
# -2.844773910105713
# -2.4922655746988664
# -2.188946359709936
# -1.925498852434973
# -1.6986174988815577
# -1.5059032819910871
# -1.3426399328263146
# -1.2087286038044531
# -1.0957843730233114
# -1.0060503732439188
# -0.9345016493035923
# -0.8806320181117822
# -0.842645536035028
# -0.8196979437267558
# -0.8115727344974712
# -0.817282565735904
# -0.8379498912895758
# -0.8728781307977511
# -0.9231572833316716
# -0.9903887440332603
# -1.0763598232567055
# -1.1828391735662862
# -1.312415730635304
# -1.4675658902481514
# -1.651909966962801
# -1.8682744693903248
# -2.123360982925181
# -2.4105175854116996
# -2.7480444664609815
# -3.1285791944845567
# -3.5660038686172726
# -4.056746316887839
# -4.604314234101597
# -5.217488102872125
# -5.886163338562558
# -6.6236735964195175
# -7.415262363325258
# -8.270150022214684
# -9.174013361120815
# -10.125671383982823
# -10.630222316925277
# -9.672639279107416
# -8.758387658750626
# -7.889319918810489
# -7.074840783808896
# -6.31478168030877
# -5.6127224837791925
# -4.971231544785974
# -4.3887810591395
# -3.864911822082044
# -3.3955963707477386
# -2.980402551653981
# -2.614056408131046
# -2.2911699725105823
# -2.012305301523715
# -1.7689597226165936
# -1.5602685388491473
# -1.3824077341440302
# -1.2313310405718116
# -1.104611854479805
# -0.9999986644126072
# -0.9140492937703634
# -0.8457375687160802
# -0.7940352924669327
# ep_rew:  -732.9296162288312
# traj errors:  tensor(1.0176, device='cuda:0', grad_fn=<AddBackward0>) tensor(9.3407, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.0763, device='cuda:0', grad_fn=<MeanBackward0>) tensor(229.3512, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-3.8229, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-225.4519, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -7.208242934763995
# -7.49955853960086
# -7.83773840702372
# -8.217325937649463
# -8.631635642824243
# trans:  [-0.99608316  0.08842141  1.49615129] tensor([-0.9361,  0.0161,  1.5042], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -9.077466067543577 tensor(-9.1463, device='cuda:0', grad_fn=<MeanBackward1>)
# -9.077466067543577
# -9.54899549679996
# -10.034228695766748
# -9.70124624156771
# -9.234227776104273
# -8.780005854566605
# -8.346248174046798
# -7.937472400612649
# -7.562759175806901
# -7.225518880256664
# -6.93445525424293
# -6.690196298565181
# -6.488891215441313
# -6.342056914997324
# -6.250733816113639
# -6.216354658939362
# -6.239627624540919
# -6.316704298999303
# -6.451937340426344
# -6.643101143265187
# -6.883371536328848
# -7.165022349880408
# -7.502590999968002
# -7.870149918913044
# -8.286917019804212
# -8.729842760799785
# -9.202587970384462
# -9.695388197416296
# -10.05036822882383
# -9.559868109487669
# -9.078863826673075
# -8.617522249245557
# -8.182387860080512
# -7.779699066381903
# -7.418448322538246
# -7.094571891302292
# -6.816982370257885
# -6.588088135199459
# -6.408481643005865
# -6.284922804570262
# -6.213292794700682
# -6.191913317733812
# -6.223178570155183
# -6.316142972563237
# -6.461774072983727
# -6.657231989880921
# -6.910110647965659
# -7.209009619831304
# -7.560267848196638
# -7.948147342403641
# -8.366319830926605
# -8.821807482082296
# -9.30413658352359
# -9.806966936200338
# -9.949120968727406
# -9.450923952195517
# -8.96600822036429
# -8.499165960590524
# -8.057721742914985
# -7.647896510925541
# -7.275157687847114
# -6.944174399040054
# -6.658814936445881
# -6.421298097044296
# -6.233813837338599
# -6.101945855848985
# -6.0291198396469365
# -6.015954158764923
# -6.065024420380782
# -6.1670846299436946
# -6.334236501634811
# -6.545307899802269
# -6.820291493344745
# -7.138994405838209
# -7.514255625532978
# -7.926078538203001
# -8.369185697206214
# -8.845790675937074
# -9.348940098600215
# -9.866874074914229
# -9.905754902543325
# -9.392609772892678
# -8.896104057268062
# -8.424162105917643
# -7.981305419769794
# -7.575455846511496
# -7.210474056444751
# -6.885709712081664
# -6.610154309263361
# -6.389773502365632
# -6.217479820186784
# -6.100794401844948
# -6.0353860588950985
# -6.031714451277864
# -6.083611922645462
# -6.194361595967684
# -6.358343781622476
# -6.578398629317082
# -6.849781283794856
# -7.173808228764511
# -7.547494083357732
# -7.962292551153074
# -8.421178194709848
# -8.911087157671858
# -9.42942497150574
# -9.965747381273427
# -9.829051202597357
# -9.300996791320932
# -8.790990952573848
# -8.309644765044547
# -7.8568436521420475
# -7.4369417755316425
# -7.062152791499311
# -6.7284369340673695
# -6.449555229036013
# -6.219228258852628
# -6.0448531618861985
# -5.9280871984782015
# -5.872619983757438
# -5.878913808632016
# -5.9520441538857485
# -6.073984568200257
# -6.261702255673484
# -6.501055996879645
# -6.799412627653287
# -7.143464469903216
# -7.529956655179644
# -7.965515085634815
# -8.445003096368737
# -8.956094858564018
# -9.492320258863689
# -10.04487276487323
# -9.766188472915696
# -9.232440055338072
# -8.711466773203808
# -8.22003042013132
# -7.757522457664567
# -7.337101205063384
# -6.955844723471803
# -6.6259350697305255
# -6.345233310143935
# -6.116422223407665
# -5.945065054382361
# -5.827988126879523
# -5.769080537746477
# -5.771024699781681
# -5.83462591742942
# -5.9605944157155175
# -6.137364746244099
# -6.382543995033718
# -6.672775449900644
# -7.024165918103446
# -7.425211349364212
# -7.872937795177982
# -8.366287364858671
# -8.89079267717756
# -9.444905557867784
# -10.025009340333035
# -9.820301034028086
# -9.256565317303693
# -8.715377435077693
# -8.198736466744712
# -7.714092760611379
# -7.267963575858086
# -6.865923350668115
# -6.512578626998131
# -6.2106292853574985
# -5.9626909019999665
# -5.775476151080114
# -5.652880797243864
# -5.596225332767727
# -5.60705079055724
# -5.684876517474534
# -5.829753527761039
# -6.03863318492366
# -6.307172389754797
# -6.6390542531276
# -7.022379657240585
# -7.4532431453475105
# -7.9413690325461435
# -8.460561942959442
# -9.021692742397263
# -9.604185202162789
# -10.20919735879884
# -9.671607933582084
# -9.092011920195969
# -8.535813190201301
# -8.013152209524018
# -7.5267595693581
# -7.080089634238692
# -6.682130064266795
# -6.338197769099575
# -6.0517037125973685
# -5.817383419063044
# ep_rew:  -1498.0687298955033
# traj errors:  tensor(2.7828, device='cuda:0', grad_fn=<AddBackward0>) tensor(21.3087, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.0703, device='cuda:0', grad_fn=<MeanBackward0>) tensor(277.0618, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-2.4468, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-274.5447, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -5.247096352591969
# -5.276852183991454
# -5.337041898170492
# -5.429528014793859
# -5.554296691086716
# trans:  [-0.74909746 -0.6624598  -0.72515363] tensor([-0.7901, -0.7179, -0.7900], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -5.709553270099716 tensor(-5.5360, device='cuda:0', grad_fn=<MeanBackward1>)
# -5.709553270099716
# -5.900866633294944
# -6.1193348584972025
# -6.373712228746881
# -6.658239648155891
# -6.971111681087202
# -7.313613289278091
# -7.685389753490941
# -8.081219998432283
# -8.500354861112532
# -8.940260246382387
# -9.40244712953695
# -9.876251267278809
# -9.857331777123765
# -9.38756732073952
# -8.929153375312891
# -8.486317874577388
# -8.062378909545265
# -7.660272636025812
# -7.282537540656472
# -6.931312606676169
# -6.6083490673639185
# -6.315034583632841
# -6.052427914233921
# -5.821301548768937
# -5.622189399977358
# -5.455436518118777
# -5.321247875943869
# -5.219733531228435
# -5.150947847096721
# -5.11492088244304
# -5.11168051200758
# -5.141264272122463
# -5.20372034635489
# -5.299097513233607
# -5.4274071445488845
# -5.588682770938027
# -5.782753001394964
# -6.009384117270195
# -6.2649101605109445
# -6.558991220242679
# -6.880313293696834
# -7.230659479438404
# -7.612591554647521
# -8.015441078949268
# -8.447767981979265
# -8.905104659431673
# -9.38155277057248
# -9.873955423959087
# -9.879237816843904
# -9.391514335060547
# -8.916230615083549
# -8.457350621792683
# -8.01829262356286
# -7.60206747709106
# -7.21126211627899
# -6.848038143351654
# -6.514145223408338
# -6.21094802830737
# -5.939464614980003
# -5.700413458102637
# -5.490541163793703
# -5.321738353833878
# -5.1832296553255235
# -5.078070736169032
# -5.006267632550269
# -4.967815500275481
# -4.962723043923506
# -4.991025945863287
# -5.052788676702839
# -5.1448645961526545
# -5.2781761654877
# -5.441670657182241
# -5.637375550793278
# -5.869215915929154
# -6.1343036947536165
# -6.430083540056739
# -6.756585222967217
# -7.117243324112021
# -7.510089463961874
# -7.931675653346959
# -8.379368899695946
# -8.851059298654262
# -9.344945447933288
# -9.856629938740737
# -9.91447812473265
# -9.4097828153982
# -8.916160429448869
# -8.439778587877155
# -7.986662443867089
# -7.5560891250846085
# -7.15191683771816
# -6.776336113344916
# -6.4311004793465445
# -6.117555883803722
# -5.836682591114629
# -5.589146519280479
# -5.375356542452032
# -5.195524146947554
# -5.049721971598164
# -4.937938115375687
# -4.860123574336995
# -4.81623069874442
# -4.806241081436911
# -4.83018176743139
# -4.888129105791258
# -4.9801999634020575
# -5.106530416442986
# -5.267242464533537
# -5.462399805764704
# -5.691954284456311
# -5.95568526995533
# -6.249451231173314
# -6.58607049956628
# -6.950417231815949
# -7.348236581368479
# -7.770388842032968
# -8.221244148234227
# -8.699567163537479
# -9.200546671845762
# -9.719785256938811
# -10.066829076151155
# -9.543913607268776
# -9.033750191699376
# -8.540465205242485
# -8.067776379182723
# -7.61895374759701
# -7.196796749682985
# -6.803628646868423
# -6.441308321086876
# -6.111258344010129
# -5.811738196195753
# -5.551829094699387
# -5.322425318197717
# -5.1285605374370515
# -4.97320077154751
# -4.850174480348699
# -4.761575309493817
# -4.707313240721995
# -4.687335231989852
# -4.701645937187652
# -4.750315624013961
# -4.832108230251978
# -4.951667369372518
# -5.104621102805203
# -5.29043314529372
# -5.5164284474465255
# -5.774955916509961
# -6.066053657297295
# -6.39266885880185
# -6.755871206444061
# -7.156975232944382
# -7.5803143834046764
# -8.036451731191965
# -8.51958598103698
# -9.026622808267938
# -9.552868387619288
# -10.099127329051244
# -9.71180745655614
# -9.183935493799549
# -8.672380606153247
# -8.181074319643027
# -7.7134899249527145
# -7.272613198729987
# -6.860931213087514
# -6.480439724658308
# -6.132668363977252
# -5.8187216034759945
# -5.539332439870363
# -5.294925011156323
# -5.085682037025713
# -4.911613008876127
# -4.772619389586562
# -4.668553611128211
# -4.59926927371187
# -4.564660565350251
# -4.564321251931607
# -4.599471123141783
# -4.6690602654980164
# -4.7736523480093025
# -4.913483739695308
# -5.088791901267955
# -5.299763072970893
# -5.5464697563992855
# -5.828800504561282
# -6.144733908776706
# -6.498167151745844
# -6.882791431630205
# -7.304606969071293
# -7.751488688555567
# -8.229774858677878
# -8.73365564332048
# -9.261388219196393
# -9.811071963071196
# ep_rew:  -1337.6163653789847
# traj errors:  tensor(1.4743, device='cuda:0', grad_fn=<AddBackward0>) tensor(11.8782, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.1979, device='cuda:0', grad_fn=<MeanBackward0>) tensor(260.8301, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.6689, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-258.9633, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -2.261106532411976
# -2.4816116150573237
# -2.7500779798046975
# -3.070613936880272
# -3.447448491601343
# trans:  [-0.39445716  0.91891433  2.19077582] tensor([-0.3674,  0.8883,  2.2184], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -3.8810198864233487 tensor(-3.9033, device='cuda:0', grad_fn=<MeanBackward1>)
# -3.8810198864233487
# -4.386274387537746
# -4.958683974402451
# -5.602730036149359
# -6.32010312423917
# -7.10701544106039
# -7.964665626518954
# -8.884597357957635
# -9.858811486574005
# -10.87783297427267
# -9.982852723124385
# -9.028403092617866
# -8.120374948397123
# -7.266379241048883
# -6.472451186191057
# -5.741016129325694
# -5.076813871877762
# -4.4802761036848375
# -3.950861734960116
# -3.4863921212075604
# -3.0847602986363643
# -2.7407459630331985
# -2.450722425493918
# -2.210465532819578
# -2.0159214601036957
# -1.8641671610129122
# -1.7506295936729384
# -1.6739977288845032
# -1.6331161039739959
# -1.625247036055383
# -1.6502197261231997
# -1.7109094719252544
# -1.8082291149855125
# -1.943455602294899
# -2.1207503526807994
# -2.342926955657409
# -2.6141497998891428
# -2.939964719148836
# -3.322296040427687
# -3.7658951903301494
# -4.278170519329451
# -4.857739877352103
# -5.511798628855661
# -6.240780210326289
# -7.045293337560011
# -7.919321605302174
# -8.859926064366494
# -9.857006588297532
# -10.901156898706152
# -10.043465146468881
# -9.064520560907324
# -8.133780759630879
# -7.259054436869806
# -6.446514031725627
# -5.700487258626877
# -5.023373267625275
# -4.415701245830268
# -3.876321867981614
# -3.4026995926022545
# -2.9912621642070185
# -2.637763546539203
# -2.337624823032044
# -2.086229885245836
# -1.8758000825268937
# -1.708652783826888
# -1.5787815306348483
# -1.4843091306709875
# -1.4234740051108286
# -1.3938903351478211
# -1.3968801991355593
# -1.429058975355244
# -1.4946189818488191
# -1.5912462381512136
# -1.7224740508793164
# -1.8916073826279747
# -2.1025315245412877
# -2.357567508953286
# -2.6626796014106553
# -3.02285639627135
# -3.44310844017046
# -3.9245744903673945
# -4.483162314917096
# -5.111658313983085
# -5.820378910772227
# -6.606295368672105
# -7.469588375858387
# -8.403552940567106
# -9.401164921787606
# -10.453105830980721
# -10.568701181595092
# -9.543038996727988
# -8.563657256762518
# -7.639240067779861
# -6.776900961813597
# -5.979474867460887
# -5.25286528769696
# -4.598626996487541
# -4.016585999937012
# -3.5052170142380277
# -3.059678634963897
# -2.677250464371035
# -2.3522813625681156
# -2.0794918188265337
# -1.8545162975416243
# -1.6729219522070549
# -1.53013859963811
# -1.4226078078228064
# -1.3481593181907736
# -1.303868493491777
# -1.2893489257321775
# -1.303835297428142
# -1.3480531596873688
# -1.423280182018394
# -1.5313322572192816
# -1.6763527709539168
# -1.8618676884468892
# -2.090326484020122
# -2.3685315081502405
# -2.7010625094377323
# -3.0935556200825514
# -3.549257337217188
# -4.074347725806867
# -4.67590739126372
# -5.354211891269362
# -6.110953453354967
# -6.946259149103125
# -7.855544100097729
# -8.836630041499301
# -9.879963006252979
# -10.975192040417529
# -10.146752304795532
# -9.120038301789682
# -8.14539622667261
# -7.231003481674814
# -6.3832757233609225
# -5.6066166598571545
# -4.903311773330034
# -4.273588575650658
# -3.7158316145088053
# -3.2269128490867964
# -2.802584430892915
# -2.4374182141808793
# -2.1263239848000026
# -1.8631423975602996
# -1.6446683190186393
# -1.4660808412380086
# -1.3241030685439594
# -1.2161948426296585
# -1.137664328397605
# -1.0868607688006344
# -1.0636722796872704
# -1.0667699296571551
# -1.098177381529884
# -1.1539652494843442
# -1.2406106056810502
# -1.3626350525371447
# -1.5120409761726037
# -1.697674030759741
# -1.9239923801321273
# -2.1960298257270012
# -2.519272815305211
# -2.899472488468928
# -3.3423796745428116
# -3.8512222080380307
# -4.435787156585449
# -5.101956211197188
# -5.851806468469912
# -6.6840590528159725
# -7.598193063063989
# -8.586679091923505
# -9.642059374399073
# -10.75413883151512
# -10.458840680131669
# -9.394074679644012
# -8.38145723271244
# -7.429752049068632
# -6.545537821985779
# -5.731298926535311
# -4.993724339014796
# -4.333558103607851
# -3.749117991710612
# -3.2367446204626944
# -2.7932539431110475
# -2.4136464505552855
# -2.0896711992865074
# -1.8197160561313959
# -1.59327400406981
# -1.4100168664163237
# -1.2641069401746379
# -1.1501818310601808
# -1.0665960208619867
# -1.0095344449588788
# -0.9776962373150896
# -0.9700472909787838
# ep_rew:  -849.798970722408
# traj errors:  tensor(0.7247, device='cuda:0', grad_fn=<AddBackward0>) tensor(5.8599, device='cuda:0', grad_fn=<AddBackward0>)
# new params!
# tensor(0.0764, device='cuda:0', grad_fn=<MeanBackward0>) tensor(308.1195, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.7674, device='cuda:0', grad_fn=<MeanBackward0>)
# mse:  tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(-306.2758, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0
# -5.737622927849359
# -5.599042970646047
# -5.552463970051324
# -5.601201495868688
# -5.743066717726066
# trans:  [-0.79232232  0.61010273  1.09478159] tensor([-0.7121,  0.6446,  0.9160], device='cuda:0', grad_fn=<MeanBackward1>)
# r:  -5.977285835906129 tensor(-5.8638, device='cuda:0', grad_fn=<MeanBackward1>)
# -5.977285835906129
# -6.298794952841487
# -6.714695766899154
# -7.200474174227515
# -7.7740359564276105
# -8.407967613990479
# -9.096360567383577
# -9.828943313228653
# -10.257103034786883
# -9.542874393247802
# -8.844670644053751
# -8.176140322093072
# -7.553333099110962
# -6.986566809179231
# -6.489740329898534
# -6.076565062836719
# -5.7623589394802295
# -5.544181602802401
# -5.439565175666643
# -5.450066343059136
# -5.577074681031478
# -5.819271875868337
# -6.171204799966655
# -6.628854224109785
# -7.185818169558945
# -7.81354812918416
# -8.526221840580304
# -9.294685258902616
# -10.108658306127104
# -10.129006405227926
# -9.35501839612244
# -8.601476868427612
# -7.885471293349959
# -7.222889573300119
# -6.627720768729366
# -6.111560518570841
# -5.683423485062181
# -5.349873113434013
# -5.115391094259794
# -4.982856356403872
# -4.953992894746316
# -5.029667557369138
# -5.208969990184882
# -5.495487671708356
# -5.881964529709334
# -6.364686760363152
# -6.939731607764762
# -7.594854393955369
# -8.33229668026276
# -9.14075453164705
# -10.000911945282498
# -10.349374713231787
# -9.524297276521073
# -8.717986876117557
# -7.948209978041033
# -7.23331184226614
# -6.584971368918086
# -6.019638194611623
# -5.552347111612792
# -5.193446317412047
# -4.956222729865168
# -4.843345251652139
# -4.856386078210123
# -4.996169013768168
# -5.259918336605598
# -5.646340620183332
# -6.152915883504866
# -6.772812273338555

# %%
def rollout_policy(states):
    Kp = 1.
    Kd = 0.1
    th, dth = np.atan2(states[:,1],states[:,0]),states[:,3]
    return -Kp*th -Kd*dth

# %%
rollout_states =
